# %%
# install module pandasai and google-generativeai in case they're not available
try:
  import pandasai
  import google.generativeai
except ModuleNotFoundError:
  if 'google.colab' in str(get_ipython()):
    # %pip install pandasai google.generativeai
# Out:
# Collecting pandasai
#   Downloading pandasai-2.4.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: google.generativeai in /usr/local/lib/python3.11/dist-packages (0.8.4)
# Collecting astor<0.9.0,>=0.8.1 (from pandasai)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: duckdb<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pandasai) (1.1.3)
# Collecting faker<20.0.0,>=19.12.0 (from pandasai)
#   Downloading Faker-19.13.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in /usr/local/lib/python3.11/dist-packages (from pandasai) (3.1.5)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from pandasai) (3.10.0)
# Requirement already satisfied: openai<2 in /usr/local/lib/python3.11/dist-packages (from pandasai) (1.61.1)
# Collecting pandas==1.5.3 (from pandasai)
#   Downloading pandas-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting pillow<11.0.0,>=10.1.0 (from pandasai)
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.11/dist-packages (from pandasai) (2.10.6)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from pandasai)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from pandasai) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from pandasai) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from pandasai) (2.0.38)
# Requirement already satisfied: sqlglot<26.0.0,>=25.0.3 in /usr/local/lib/python3.11/dist-packages (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai) (25.6.1)
# Collecting torch==2.4.1 (from pandasai)
#   Downloading torch-2.4.1-cp311-cp311-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3->pandasai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3->pandasai) (2025.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3->pandasai) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1->pandasai) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1->pandasai) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1->pandasai) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1->pandasai) (3.4.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch==2.4.1->pandasai) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.4.1->pandasai)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.4.1->pandasai)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.4.1->pandasai)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.4.1->pandasai)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.4.1->pandasai)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.4.1->pandasai)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.4.1->pandasai)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.4.1->pandasai)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.4.1->pandasai)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.4.1->pandasai)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.4.1->pandasai)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch==2.4.1->pandasai)
#   Downloading triton-3.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.1->pandasai) (12.5.82)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google.generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google.generativeai) (2.24.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google.generativeai) (2.160.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google.generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google.generativeai) (4.25.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google.generativeai) (4.67.1)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google.generativeai) (1.26.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google.generativeai) (1.67.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google.generativeai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google.generativeai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google.generativeai) (4.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.3->pandasai) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (3.2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai<2->pandasai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2->pandasai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai<2->pandasai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai<2->pandasai) (0.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai<2->pandasai) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1->pandasai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1->pandasai) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->pandasai) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->pandasai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->pandasai) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->pandasai) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4->pandasai) (3.1.1)
# Collecting sqlglotrs==0.2.8 (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai)
#   Downloading sqlglotrs-0.2.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (258 bytes)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google.generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google.generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google.generativeai) (4.1.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google.generativeai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google.generativeai) (1.62.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai<2->pandasai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2->pandasai) (0.14.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google.generativeai) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->pandas==1.5.3->pandasai) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.4.1->pandasai) (1.3.0)
# Downloading pandasai-2.4.2-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.7/193.7 kB 7.6 MB/s eta 0:00:00
# Downloading pandas-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 33.6 MB/s eta 0:00:00
# Downloading torch-2.4.1-cp311-cp311-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 60.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 35.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 37.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 15.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 7.9 MB/s eta 0:00:00
# Downloading triton-3.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 5.8 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading Faker-19.13.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 69.3 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 89.8 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading sqlglotrs-0.2.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.9/332.9 kB 21.7 MB/s eta 0:00:00
# Installing collected packages: triton, sqlglotrs, python-dotenv, pillow, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, astor, pandas, nvidia-cusolver-cu12, nvidia-cudnn-cu12, faker, torch, pandasai
#   Attempting uninstall: triton
#     Found existing installation: triton 3.1.0
#     Uninstalling triton-3.1.0:
#       Successfully uninstalled triton-3.1.0
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.1.0
#     Uninstalling pillow-11.1.0:
#       Successfully uninstalled pillow-11.1.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.1+cu124
#     Uninstalling torch-2.5.1+cu124:
#       Successfully uninstalled torch-2.5.1+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 1.5.3 which is incompatible.
# torchvision 0.20.1+cu124 requires torch==2.5.1, but you have torch 2.4.1 which is incompatible.
# xarray 2025.1.2 requires pandas>=2.1, but you have pandas 1.5.3 which is incompatible.
# mizani 0.13.1 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# torchaudio 2.5.1+cu124 requires torch==2.5.1, but you have torch 2.4.1 which is incompatible.
# cudf-cu12 24.12.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# Successfully installed astor-0.8.1 faker-19.13.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvtx-cu12-12.1.105 pandas-1.5.3 pandasai-2.4.2 pillow-10.4.0 python-dotenv-1.0.1 sqlglotrs-0.2.8 torch-2.4.1 triton-3.0.0

# %%
from pandasai.llm.google_gemini import GoogleGemini
from pandasai import SmartDataframe
from google.colab import userdata
import pandas as pd
import google.generativeai as genai

# %%
genai.configure(api_key=userdata.get('GOOGLE_API_KEY'))

# Available Gemini models can found in https://ai.google.dev/gemini-api/docs/models/gemini
available_models = genai.list_models()
for m in available_models:
    print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental
# models/embedding-001
# models/text-embedding-004
# models/aqa
# models/imagen-3.0-generate-002

# %%
chat = genai.GenerativeModel("gemini-1.5-pro-latest")

# %%
llm = GoogleGemini(api_key=userdata.get('GOOGLE_API_KEY'))

# %%
url = "https://drive.google.com/file/d/1Eeq986GzG7g1xqcfHuJXR7P4Lk0wBS30/view?usp=sharing"
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
covidtotal = pd.read_csv(path)
covidtotal.head()
# Out:
#   iso_code    lastdate        location  total_cases  total_deaths  \
# 0      AFG  2024-02-04     Afghanistan     231539.0        7982.0
# 1      ALB  2024-01-28         Albania     334863.0        3605.0
# 2      DZA  2023-12-03         Algeria     272010.0        6881.0
# 3      ASM  2023-09-17  American Samoa       8359.0          34.0
# 4      AND  2023-05-07         Andorra      48015.0         159.0
#
#    total_cases_pm  total_deaths_pm  population  pop_density  median_age  \
# 0        5629.611          194.073    41128772       54.422        18.6
# 1      117813.348         1268.331     2842318      104.871        38.0
# 2        6057.694          153.241    44903228       17.348        29.1
# 3      188712.044          767.581       44295      278.205         NaN
# 4      601367.684         1991.408       79843      163.755         NaN
#
#    gdp_per_capita  hosp_beds  vac_per_hund  aged_65_older  life_expectancy  \
# 0        1803.987       0.50           NaN          2.581            64.83
# 1       11803.431       2.89           NaN         13.188            78.57
# 2       13913.839       1.90           NaN          6.211            76.88
# 3             NaN        NaN           NaN            NaN            73.74
# 4             NaN        NaN           NaN            NaN            83.73
#
#    hum_dev_ind          region
# 0        0.511      South Asia
# 1        0.795  Eastern Europe
# 2        0.748    North Africa
# 3          NaN   Oceania / Aus
# 4        0.868  Western Europe

# %%
response = model.generate_content("Algeria itu ada dimana?")
print(response.text)  # Extract and print the generated text
# Out:
# Algeria terletak di Afrika Utara.

# %%
covidtotal.set_index("iso_code", inplace=True)

# %%
covidtotalsdf = SmartDataframe(covidtotal, config={"llm": llm, "temperature": 0, "verbose": False, "output_type": "plot", "custom_whitelisted_dependencies":["scikit-learn","statsmodels"], "enable_cache": True, "use_error_correction_framework": False})

# %%
if covidtotalsdf is not None:
    print(covidtotalsdf.head())
else:
    print("SmartDataframe is None. Check your setup.")
# Out:
#      lastdate                      location  total_cases  total_deaths  \
# 0  2023-08-13                       Bolivia      20550.0        1462.0
# 1  2023-01-01            Dominican Republic       9515.0        9436.0
# 2  2023-10-08                          Laos      99338.0        5938.0
# 3  2023-05-07                       Iceland     350499.0       35934.0
# 4  2022-12-04  Democratic Republic of Congo       6265.0        2986.0
#
#    total_cases_pm  total_deaths_pm  population  pop_density  median_age  \
# 0       36784.149         2251.777     5023108      494.869        28.2
# 1       55423.710          194.073     3684041       41.285         NaN
# 2      167980.564         2742.840      107135       16.955        17.6
# 3      128872.507           89.116     6812344          NaN        33.4
# 4      626793.139          153.241       63329       87.176        16.4
#
#    gdp_per_capita  hosp_beds  vac_per_hund  aged_65_older  life_expectancy  \
# 0       10581.936       6.30        269.97          4.800            80.10
# 1        3299.464        NaN         93.23          9.954            82.97
# 2       16277.671       2.96           NaN         19.985            67.11
# 3       22267.037       3.70        163.59         13.188            76.88
# 4             NaN       1.40         69.68            NaN              NaN
#
#    hum_dev_ind          region
# 0          NaN       West Asia
# 1        0.704      South Asia
# 2        0.926  Central Africa
# 3        0.744     West Africa
# 4        0.868    North Africa

# %%
covidtotalsdf.chat("Mohon descriptive statistics dari data")
# Out:
#         total_cases  total_deaths  total_cases_pm  total_deaths_pm  \
# count  2.310000e+02  2.310000e+02      231.000000       231.000000
# mean   3.351599e+06  3.021420e+04   206177.794623      1261.778390
# std    1.148321e+07  1.047789e+05   203858.096252      1314.981529
# min    4.000000e+00  0.000000e+00      354.487000         0.000000
# 25%    2.567150e+04  1.775000e+02    21821.863000       141.177000
# 50%    1.914960e+05  1.937000e+03   133946.251000       827.046000
# 75%    1.294286e+06  1.415000e+04   345689.831000      1997.513000
# max    1.034368e+08  1.127152e+06   763475.441000      6507.656000
#
#          population   pop_density  median_age  gdp_per_capita   hosp_beds  \
# count  2.310000e+02    209.000000  194.000000      191.000000  170.000000
# mean   3.424609e+07    323.603359   30.341753    18614.958990    3.014576
# std    1.376530e+08   1468.427340    9.117782    19470.167828    2.434476
# min    4.700000e+01      0.137000   15.100000      661.240000    0.100000
# 25%    3.702075e+05     37.728000   22.050000     3821.198000    1.300000
# 50%    5.434324e+06     88.125000   29.600000    12236.706000    2.398500
# 75%    2.197870e+07    222.873000   38.700000    27012.304500    3.965250
# max    1.425887e+09  19347.500000   48.200000   116935.600000   13.800000
#
#        vac_per_hund  aged_65_older  life_expectancy  hum_dev_ind
# count     13.000000     188.000000        227.00000   187.000000
# mean     196.476923       8.675835         73.64652     0.721251
# std       96.305392       6.150235          7.42389     0.149669
# min       38.470000       1.144000         53.28000     0.394000
# 25%      155.720000       3.496750         69.54500     0.601500
# 50%      214.070000       6.258500         75.05000     0.740000
# 75%      227.810000      13.990500         79.28500     0.828500
# max      406.390000      27.049000         86.75000     0.957000

# %%
covidtotalsdf.chat("Ini data apa?")
# Out:
# 'The data is a list of dataframes with information about the COVID-19 pandemic in different countries.'

# %%
covidtotalsdf.chat("Show me locations with the five most total cases from highest to lowest and only show the first 4 columns")
# Out:
#             lastdate       location  total_cases  total_deaths
# iso_code
# USA       2023-05-14  United States  103436829.0     1127152.0
# CHN       2024-02-04          China   99329249.0      121933.0
# IND       2024-02-04          India   45026139.0      533454.0
# FRA       2023-06-25         France   38997490.0      167985.0
# DEU       2023-07-02        Germany   38437756.0      174979.0

# %%
covidtotalsdf.chat("Show total cases pm, total deaths pm, and location for locations with the 10 highest total cases pm.")
# Out:
#           total_cases_pm  total_deaths_pm        location
# iso_code
# BRN           763475.441          396.435          Brunei
# CYP           760161.472         1523.426          Cyprus
# SMR           750727.219         3739.982      San Marino
# AUT           680262.588         2520.690         Austria
# KOR           667207.062          693.495     South Korea
# FRO           652484.139          527.138  Faeroe Islands
# SVN           639407.730         4697.046        Slovenia
# GIB           628882.700         3458.090       Gibraltar
# MTQ           626793.139         3003.984      Martinique
# LUX           603439.463         1544.161      Luxembourg

# %%
covidtotalsabb = covidtotalsdf.chat("Select total cases pm, total deaths pm, and location.")
type(covidtotalsabb)
# Out:
# pandas.core.frame.DataFrame

# %%
covidtotalsabb
# Out:
#           total_cases_pm  total_deaths_pm           location
# iso_code
# AFG             5629.611          194.073        Afghanistan
# ALB           117813.348         1268.331            Albania
# DZA             6057.694          153.241            Algeria
# ASM           188712.044          767.581     American Samoa
# AND           601367.684         1991.408            Andorra
# ...                  ...              ...                ...
# VNM           118386.518          440.039            Vietnam
# WLF           306140.048          689.893  Wallis and Futuna
# YEM              354.487           64.072              Yemen
# ZMB            17449.783          203.270             Zambia
# ZWE            16314.719          351.520           Zimbabwe
#
# [231 rows x 3 columns]

# %%
covidtotalsdf.chat("Show total cases pm and location where total cases pm greater than 95th percentile from the highest to the lowest total cases pm.")
# Out:
#             lastdate        location  total_cases  total_deaths  \
# iso_code
# BRN       2024-02-04          Brunei     342802.0         178.0
# CYP       2024-01-07          Cyprus     681110.0        1365.0
# SMR       2023-11-26      San Marino      25292.0         126.0
# AUT       2023-07-02         Austria    6081287.0       22534.0
# KOR       2023-09-10     South Korea   34571873.0       35934.0
# FRO       2022-03-06  Faeroe Islands      34658.0          28.0
# SVN       2024-01-28        Slovenia    1355444.0        9957.0
# GIB       2023-04-09       Gibraltar      20550.0         113.0
# MTQ       2023-06-25      Martinique     230354.0        1104.0
# LUX       2024-01-28      Luxembourg     390788.0        1000.0
# FRA       2023-06-25          France   38997490.0      167985.0
# AND       2023-05-07         Andorra      48015.0         159.0
#
#           total_cases_pm  total_deaths_pm  population  pop_density  \
# iso_code
# BRN           763475.441          396.435      449002       81.347
# CYP           760161.472         1523.426      896007      127.657
# SMR           750727.219         3739.982       33690      556.667
# AUT           680262.588         2520.690     8939617      106.749
# KOR           667207.062          693.495    51815808      527.967
# FRO           652484.139          527.138       53117       35.308
# SVN           639407.730         4697.046     2119843      102.619
# GIB           628882.700         3458.090       32677     3457.100
# MTQ           626793.139         3003.984      367512          NaN
# LUX           603439.463         1544.161      647601      231.447
# FRA           603427.621         2599.316    67813000      122.578
# AND           601367.684         1991.408       79843      163.755
#
#           median_age  gdp_per_capita  hosp_beds  vac_per_hund  aged_65_older  \
# iso_code
# BRN             32.4       71809.251       2.70           NaN          4.591
# CYP             37.3       32415.132       3.40           NaN         13.416
# SMR              NaN       56861.470       3.80           NaN            NaN
# AUT             44.4       45436.686       7.37           NaN         19.202
# KOR             43.4       35938.374      12.27           NaN         13.914
# FRO              NaN             NaN        NaN           NaN            NaN
# SVN             44.5       31400.840       4.50           NaN         19.062
# GIB              NaN             NaN        NaN           NaN            NaN
# MTQ             45.7             NaN        NaN           NaN            NaN
# LUX             39.7       94277.965       4.51           NaN         14.312
# FRA             42.0       38605.671       5.98        227.81         19.718
# AND              NaN             NaN        NaN           NaN            NaN
#
#           life_expectancy  hum_dev_ind          region
# iso_code
# BRN                 75.86        0.838       East Asia
# CYP                 80.98        0.887  Eastern Europe
# SMR                 84.97          NaN  Western Europe
# AUT                 81.54        0.922  Western Europe
# KOR                 83.03        0.916       East Asia
# FRO                 80.67          NaN  Western Europe
# SVN                 81.32        0.917  Eastern Europe
# GIB                 79.93          NaN  Western Europe
# MTQ                 82.54          NaN       Caribbean
# LUX                 82.25        0.916  Western Europe
# FRA                 82.66        0.901  Western Europe
# AND                 83.73        0.868  Western Europe

# %%
covidtotalsdf.chat("Summarize values for total cases pm and total deaths pm. Do not show any plots")
# Out:
#                             0
# total_cases_pm   4.762707e+07
# total_deaths_pm  2.914708e+05

# %%
covidtotalsdf.chat("Show sum of total cases and total deaths by region and rank by total death.")
# Out:
#                  total_cases  total_deaths
# region
# North America    115917286.0     1516239.0
# South America     68751186.0     1354440.0
# Western Europe   189405185.0     1124545.0
# Eastern Europe    62360832.0      969011.0
# South Asia        51507806.0      632374.0
# East Asia        205704775.0      604355.0
# West Asia         41080675.0      360258.0
# Southern Africa    5627277.0      126376.0
# North Africa       3727507.0       83872.0
# Central America    4285644.0       54500.0
# Central Asia       3070921.0       40365.0
# Caribbean          4258031.0       32584.0
# Oceania / Aus     14741706.0       31730.0
# East Africa        2186107.0       28519.0
# West Africa         953756.0       12184.0
# Central Africa      640579.0        8128.0

# %%
from sklearn.datasets import load_iris

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB
# None
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
response = model.generate_content("Apa itu Iris dataset")
print(response.text)  # Extract and print the generated text
# Out:
# Dataset Iris adalah salah satu dataset paling terkenal dan sering digunakan dalam pembelajaran mesin dan statistik.  Dataset ini berisi pengukuran dari 150 bunga iris, dengan 50 bunga dari masing-masing tiga spesies:
#
# * **Iris setosa**
# * **Iris versicolor**
# * **Iris virginica**
#
# Untuk setiap bunga, dataset mencatat empat fitur (variabel prediktif):
#
# * **Panjang sepal (cm)**
# * **Lebar sepal (cm)**
# * **Panjang petal (cm)**
# * **Lebar petal (cm)**
#
# Tujuan umum penggunaan dataset Iris adalah untuk membangun model klasifikasi yang dapat memprediksi spesies bunga iris berdasarkan empat fitur tersebut.  Karena dataset ini relatif kecil dan sederhana, ia sering digunakan untuk demonstrasi dan pembelajaran berbagai teknik pembelajaran mesin, seperti:
#
# * **Klasifikasi:**  Memprediksi spesies iris berdasarkan ukuran sepal dan petal.
# * **Pengelompokan (Clustering):**  Mengelompokkan bunga iris ke dalam kelompok berdasarkan kesamaan fitur mereka, tanpa mengetahui spesiesnya terlebih dahulu.
# * **Visualisasi Data:**  Memvisualisasikan data untuk mengidentifikasi pola dan hubungan antar fitur.
#
# Keunggulan Dataset Iris:
#
# * **Sederhana dan mudah dipahami:**  Dataset ini kecil dan hanya memiliki empat fitur, sehingga mudah untuk divisualisasikan dan dianalisis.
# * **Bersih dan terstruktur dengan baik:**  Data sudah bersih dan tidak ada nilai yang hilang.
# * **Mudah diakses:**  Dataset ini tersedia secara luas di banyak pustaka pembelajaran mesin, seperti scikit-learn di Python.
#
# Karena kesederhanaannya, dataset Iris sering digunakan sebagai "Hello World" dalam pembelajaran mesin,  membantu pemula untuk memahami konsep dasar dan mempraktikkan teknik-teknik dasar.  Meskipun sederhana, dataset ini tetap berguna untuk mengilustrasikan berbagai konsep penting dan menjadi dasar untuk memahami dataset yang lebih kompleks.

# %%
irisdf = SmartDataframe(df, config={"llm": llm, "temperature": 0, "verbose": False, "output_type": "plot", "custom_whitelisted_dependencies":["scikit-learn","statsmodels"], "enable_cache": True, "use_error_correction_framework": False})

# %%
irisdf.chat("Calculate mean and median values of columns.")
# Out:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# mean             5.843333          3.057333              3.758
# median           5.800000          3.000000              4.350
#
#         petal width (cm)
# mean            1.199333
# median          1.300000

# %%
irisdf.chat(" Calculate the correlations between all columns in the data")
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
irisdf.chat("Calculate correlation between sepal length and petal width.")
# Out:
# 0.8179411262715757

# %%
# install module yfinance (yahoo finance)
try:
  import yfinance
except ModuleNotFoundError:
  if 'google.colab' in str(get_ipython()):
    # %pip install yfinance

# %%
from pandasai.connectors import YahooFinanceConnector

yf_conn = YahooFinanceConnector("MSFT")

ydf = SmartDataframe(yf_conn, config={"llm": llm, "temperature": 0, "verbose": False, "output_type": "plot", "custom_whitelisted_dependencies":["scikit-learn","statsmodels"], "enable_cache": True, "use_error_correction_framework": False})
ydf.chat("What's the latest price of Microsoft?")
# Out:
# 408.2099914550781

# %%
response = model.generate_content("Apa itu ticker MSFT?")
print(response.text)  # Extract and print the generated text
# Out:
# MSFT adalah simbol ticker atau kode saham untuk **Microsoft Corporation**. Simbol ticker digunakan di bursa saham untuk mengidentifikasi perusahaan secara unik.  Jadi, ketika Anda melihat MSFT di platform perdagangan atau kutipan saham, itu merujuk pada saham Microsoft.

# %%
ydf.chat("Is there any dividend in the stock in 2024?")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2003-02-19 00:00:00-05:00   15.322393   15.359433   14.921122   15.143365
# 2003-10-15 00:00:00-04:00   18.127479   18.164727   17.817077   18.046774
# 2004-08-23 00:00:00-04:00   16.979277   17.016635   16.885882   16.960598
# 2004-11-15 00:00:00-05:00   18.972661   19.083694   18.875509   19.007359
# 2005-02-15 00:00:00-05:00   18.098434   18.154121   18.000981   18.049707
# ...                               ...         ...         ...         ...
# 2023-11-15 00:00:00-05:00  368.524213  370.360488  364.385151  366.926178
# 2024-02-14 00:00:00-05:00  405.790190  407.550291  402.309744  407.202240
# 2024-05-15 00:00:00-04:00  416.314815  422.202401  415.687200  421.475159
# 2024-08-15 00:00:00-04:00  418.961380  420.268761  416.825671  420.188934
# 2024-11-21 00:00:00-05:00  419.500000  419.779999  410.290009  412.869995
#
#                               Volume  Dividends  Stock Splits
# Date
# 2003-02-19 00:00:00-05:00   46902700       0.08           0.0
# 2003-10-15 00:00:00-04:00   57242100       0.16           0.0
# 2004-08-23 00:00:00-04:00   39572200       0.08           0.0
# 2004-11-15 00:00:00-05:00  104468000       3.08           0.0
# 2005-02-15 00:00:00-05:00   76551600       0.08           0.0
# ...                              ...        ...           ...
# 2023-11-15 00:00:00-05:00   26860100       0.75           0.0
# 2024-02-14 00:00:00-05:00   20401200       0.75           0.0
# 2024-05-15 00:00:00-04:00   22239500       0.75           0.0
# 2024-08-15 00:00:00-04:00   20752100       0.75           0.0
# 2024-11-21 00:00:00-05:00   20780200       0.83           0.0
#
# [84 rows x 7 columns]

# %%
response = model.generate_content("Dimana bisa cari restoran Padang di dekat Astra Honda Motor di Sunter Jakarta?")
print(response.text)  # Extract and print the generated text
# Out:
# Kamu bisa mencari restoran Padang dekat Astra Honda Motor Sunter, Jakarta dengan beberapa cara:
#
# * **Google Maps/Search:** Ketik "Restoran Padang dekat Astra Honda Motor Sunter" atau "Rumah Makan Padang dekat AHM Sunter". Google Maps akan menampilkan beberapa pilihan terdekat beserta rating, ulasan, dan petunjuk arah.
# * **Aplikasi pesan-antar makanan (GoFood, GrabFood, ShopeeFood, dll.):**  Masukan alamat Astra Honda Motor di Sunter sebagai lokasi pengiriman. Aplikasi ini akan menampilkan restoran Padang yang melayani pengantaran ke area tersebut.  Ini mungkin cara termudah, karena kamu bisa langsung melihat menu dan harga.
# * **Tanya orang sekitar:** Jika kamu sedang berada di dekat Astra Honda Motor Sunter, kamu bisa bertanya kepada satpam, pegawai di sekitar, atau warga sekitar untuk rekomendasi restoran Padang terdekat.  Mereka mungkin bisa memberikan informasi yang lebih lokal dan spesifik.
# * **Media sosial:** Coba cari di media sosial seperti Instagram atau Facebook dengan kata kunci seperti "Restoran Padang Sunter" atau "Kuliner Padang Sunter".  Banyak restoran yang mempromosikan diri di media sosial.
#
# Sebaiknya kamu membandingkan beberapa pilihan sebelum memutuskan, pertimbangkan faktor jarak, harga, rating, dan menu yang ditawarkan.
